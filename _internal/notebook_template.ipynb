# %% [markdown]
# # Title
# <a class="download-ipynb-button" href="../../_static/notebooks/notebook_name.ipynb" download> <i class="fas fa-download"></i> Download this notebook</a>
# >NOTE: the path to download the notebooks should always be: `../../_static/notebook_name.ipynb`. You do not need to move the notebook yourself, the `bash.sh` takes care of that.

# %%
# /// script
# requires-python = ">=3.12"
# dependencies = [
#     "matplotlib",
#     "ndv[jupyter,vispy]",
#     "numpy",
#     "scikit-image",
#     "tifffile",
# ]
# ///

# %%
import numpy as np
import ndv
img = np.random.randint(0, 255, (10, 100, 100), dtype=np.uint8)

# %%
# since ndv for now cannot be rendered when the book is build, we need to tak any cell
# that has "ndv.imshow(data)" with the tak "skip-execution" so that it is not executed
# when building the book. This tag is automatically removed when downloading the book
# with the "download" button.
ndv.imshow(img)

# %%
# the 2 cells below are the one we need to add to replace the one above so that when
# the book is built, at least the image is shown in the book. We need to tach this cell
# with "remove-input" and "remove-output" so that it is not shown in the build book.
viewer = ndv.imshow(img)

# %%
# We need to tach this cell with "remove-input" so that it is not shown in the build book.
viewer.widget().children[1].snapshot()
