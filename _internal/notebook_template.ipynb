# %% [markdown]
# # Title

# %%
# /// script
# requires-python = ">=3.12"
# dependencies = [
#     "matplotlib",
#     "ndv[jupyter,vispy]",
#     "numpy",
#     "scikit-image",
#     "tifffile",
# ]
# ///

# %% [markdown]
# # Description
# In this Notebook...
#
# ## Objectives
# - ...
# - ...
#
# ## Table of Contentss
# - ...
# - ...

# %% [markdown]
# Describe what is the next step/content of the cell (if necessary)...
#
# Can add images, screenshots of slided, ...
#
# To add an image:
# - add it to the `_static/inages/` folder
# - use the following syntax (by chnaging the `width` or `height` you can resize the image):
#
# <img src="../_static/images/example_image.png" alt="Example image" width="300px">

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Describe what is the next step/content of the cell (if necessary)...
#
# Can add images, screenshots of slided, ...

# %%
img = np.random.randint(0, 255, (10, 100, 100), dtype=np.uint8)

# %% [markdown]
# Describe what is the next step/content of the cell (if necessary)...
#
# Can add images, screenshots of slided, ...

# %%
plt.imshow(img[0], cmap="gray")
plt.axis("off")
plt.show()
