# %% [markdown]
# # Python Basics
# <div class="custom-button-row">
#     <a
#         class="custom-button custom-download-button" href="../../notebooks/4-python_basics/python_basics_notebook.ipynb" download>
#         <i class="fas fa-download"></i> Download this Notebook
#     </a>
#     <a
#     class="custom-button custom-download-button" href="https://colab.research.google.com/github/HMS-IAC/bobiac/blob/gh-pages/colab_notebooks/4-python_basics/python_basics_notebook.ipynb" target="_blank">
#         <img class="button-icon" src="../../_static/logo/icon-google-colab.svg" alt="Open in Colab">
#         Open in Colab
#     </a>
# </div>

# %%
# /// script
# requires-python = ">=3.12"
# dependencies = [
#     "matplotlib",
#     "ndv[jupyter,vispy]",
#     "scikit-image",
#     "tifffile",
# ]
# ///

# %% [markdown]
# # Description
# In this Notebook...
#
# ## Objectives
# - ...
#
# ## Table of Contentss
# - ...

# %%
import numpy as np
import ndv
import matplotlib.pyplot as plt

# %%
img = np.random.randint(0, 255, (10, 100, 100), dtype=np.uint8)
print(img.shape, img.dtype)

# %%
ndv.imshow(img)

# %%
viewer = ndv.imshow(img)

# %%
viewer.widget().children[1].snapshot()

# %%
plt.imshow(img[0], cmap="gray")
plt.axis("off")
plt.show()
